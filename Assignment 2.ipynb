# %%
a = int(input("Entered Value of a:"))
b = int(input("Enter Value of b:"))
c = int(input("Enter Value of c:"))

if a == b == c:
    print("All three numbers are equal.")
elif a == b and a > c:
    print("A and B are equal and the largest: {a}")
elif b == c and b > a:
    print("B and C are equal and the largest: {b}")
elif a == c and a > b:
    print("A and C are equal and the largest: {a}")

else:
    if a > b and a > c:
        print(f"A is the largest: {a}")
    elif b > a and b > c:
        print(f"B is the largest: {b}")
    else:
        print(f"C is the largest: {c}")
        print
# Out:
# Entered Value of a: 21
# Enter Value of b: 213
# Enter Value of c: 3212
# C is the largest: 3212
