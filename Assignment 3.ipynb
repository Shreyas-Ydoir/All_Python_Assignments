# %%
a=int(input("Side 1="))
b=int(input("Side 2="))
c=int(input("Side 3="))
def triangle() :
    if (a + b <= c) or (a + c <= b) or (b + c <= a):
        print("CONCLUTIOIN:: Not a valid triangle")
    elif a*a + b*b == c*c:
        print("Right angled triangle")
    elif a*a + c*c == b*b:
        print("CONCLUTIOIN:: Right angled triangle")
    elif c*c + b*b == a*a:
        print ("CONCLUTIOIN:: Right angled triangle")
    else :
        print("CONCLUTIOIN:: Not Right angled triangle")

def mul() :
    a=int(input("Side 1="))
    b=int(input("Side 2="))
    c=int(input("Side 3="))
    if a==0 or b==0 or c==0 :
        print("CONCLUTIOIN:: Not a triangle")
    elif a==b or b==c or a==c :
        print("CONCLUTIOIN:: The triangle is isosceles triangle")
    elif a==b==c:
        print ("CONCLUTIOIN:: The triangle is equilateral triangle")
    else :
        print("CONCLUTIOIN:: The triangle is scalene triangle")
    

triangle()
mul()
# Out:
# Side 1= 12
# Side 2= 23
# Side 3= 3123
# CONCLUTIOIN:: Not a valid triangle
